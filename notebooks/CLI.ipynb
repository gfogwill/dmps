# %%
# %load_ext autoreload
# %autoreload 2

# %%
import logging
from src.log import logger
logger.setLevel(logging.INFO)

# %%
from src.data.localdata import read_cle_file
from src.paths import interim_data_path, processed_data_path, external_data_path

# %%
year = 2017

output_filepath = processed_data_path / f'events-{year}.csv'
dataset_name = 'mbi-cle'

# clean_dir(processed_data_path / year)

data, flags = read_cle_file(external_data_path / dataset_name / f'DMPSmbiocle{year}.dat',
                                has_flag=True,
                                year=year,
                                utc_time=False)

# %%
data
# Out:
#                       10.000173    12.003411    14.407767    17.293944   \
# datetime
# 2016-12-31 21:00:00    74.898513  1402.585050  1564.636100  2494.321300
# 2016-12-31 21:10:00   776.703570  1369.090300  1544.903000  3131.172600
# 2016-12-31 21:20:00  1418.023940  1440.737700  1560.981000  2305.630250
# 2016-12-31 21:30:00   142.727695  1830.360000  1857.884200  2028.769350
# 2016-12-31 21:40:00   927.879020  1620.999300  1652.041950  2115.251600
# ...                          ...          ...          ...          ...
# 2017-12-31 20:10:00    48.344908     0.000000     0.000000     0.708021
# 2017-12-31 20:20:00    48.028609     2.104266     0.000000     2.189602
# 2017-12-31 20:30:00    60.429347     0.000000     0.000000     6.115680
# 2017-12-31 20:40:00    60.352567     1.355011     2.082188     1.420595
# 2017-12-31 20:50:00    54.559262     0.869346     0.000000     2.186294
#
#                       20.758044    24.916456    29.907444    35.898438   \
# datetime
# ...

# %%
flags
# Out:
# datetime
# 2017-01-01 00:00:00    0.0
# 2017-01-01 00:10:00    0.0
# 2017-01-01 00:20:00    0.0
# 2017-01-01 00:30:00    0.0
# 2017-01-01 00:40:00    0.5
#                       ...
# 2017-12-31 23:10:00    0.0
# 2017-12-31 23:20:00    0.0
# 2017-12-31 23:30:00    0.0
# 2017-12-31 23:40:00    0.0
# 2017-12-31 23:50:00    0.0
# Freq: 10T, Name: flag, Length: 52560, dtype: float64
